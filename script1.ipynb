# %%
from linkedin_api import Linkedin
from constants import LINKEDIN_USER_EMAIL, LINKEDIN_USER_PASS

api = Linkedin(LINKEDIN_USER_EMAIL, LINKEDIN_USER_PASS)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
First_name = 'sarnab'
Last_name = 'banerjee'

# %%
name = First_name + ' ' + Last_name

# %%
profile = api.search(params={'keywords': First_name}, limit=1)

print(profile)
# Out:
# [{'template': 'UNIVERSAL', 'actorNavigationContext': None, 'trackingUrn': 'urn:li:member:943040842', 'controlName': None, 'interstitialComponent': None, 'primaryActions': [], 'entityCustomTrackingInfo': {'memberDistance': 'OUT_OF_NETWORK', '_type': 'com.linkedin.voyager.dash.search.EntityCustomTrackingInfo', 'privacySettingsInjectionHolder': None, '_recipeType': 'com.linkedin.4caf791202c7b71e3874d4551f078f32', 'nameMatch': True}, 'title': {'textDirection': 'FIRST_STRONG', '_type': 'com.linkedin.voyager.dash.common.text.TextViewModel', 'text': 'Sarnab Banerjee', 'attributesV2': [], '_recipeType': 'com.linkedin.6a224ca38654a84754a1eb3e97c0f846', 'accessibilityTextAttributesV2': [], 'accessibilityText': 'View Sarnab Banerjee’s profile'}, 'overflowActions': [], 'searchActionType': None, 'actorInsights': [], 'insightsResolutionResults': [], 'badgeIcon': None, 'entityUrn': 'urn:li:fsd_entityResultViewModel:(urn:li:fsd_profile:ACoAADg1qUoByV5tTAP7qjYEKRXTxqlZv4xdtk8,SEARCH_SRP,DEFAULT)', 's
# ...

# %%
import pandas as pd
df = pd.DataFrame(profile)
df
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#      template                             actorNavigationContext
# 0   UNIVERSAL                                               None  \
# 1   UNIVERSAL                                               None
# 2   UNIVERSAL                                               None
# 3   CONTENT_B  {'_type': 'com.linkedin.voyager.dash.search.Na...
# 4   CONTENT_A  {'_type': 'com.linkedin.voyager.dash.search.Na...
# 5   CONTENT_B  {'_type': 'com.linkedin.voyager.dash.search.Na...
# 6   UNIVERSAL                                               None
# 7   UNIVERSAL                                               None
# 8   UNIVERSAL                                               None
# 9   UNIVERSAL                                               None
# 10  UNIVERSAL                                               None
# 11  UNIVERSAL                                               None
# 12  UNIVERSAL                                               None
#
# ...

# %%
x = df['navigationUrl'][1]

# %%
import requests
from constants import API_KEY
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
linkedin_profile_url = x
api_key = API_KEY
headers = {'Authorization': 'Bearer ' + api_key}

response = requests.get(api_endpoint,
                        params={'url': linkedin_profile_url,'skills': 'include'},
                        headers=headers)

# %%
profile_data = response.json()
profile_data
# Out:
# {'public_identifier': 'sarnab-das-042486a3',
#  'profile_pic_url': None,
#  'background_cover_image_url': None,
#  'first_name': 'sarnab',
#  'last_name': 'das',
#  'full_name': 'sarnab das',
#  'follower_count': None,
#  'occupation': 'human resources accounts and client delivery manager',
#  'headline': None,
#  'summary': None,
#  'country': 'IN',
#  'country_full_name': 'india',
#  'city': 'bombay',
#  'state': 'maharashtra',
#  'experiences': [{'starts_at': {'day': 1, 'month': 8, 'year': 2018},
#    'ends_at': None,
#    'company': 'intello group',
#    'company_linkedin_profile_url': None,
#    'title': 'human resources accounts and client delivery manager',
#    'description': None,
#    'location': None,
#    'logo_url': None}],
#  'education': [{'starts_at': {'day': 1, 'month': 1, 'year': 2012},
#    'ends_at': {'day': 1, 'month': 1, 'year': 2016},
#    'field_of_study': None,
#    'degree_name': 'bachelors',
#    'school': 'indian maritime university',
# ...

# %%
profile_data.keys()
# Out:
# dict_keys(['public_identifier', 'profile_pic_url', 'background_cover_image_url', 'first_name', 'last_name', 'full_name', 'follower_count', 'occupation', 'headline', 'summary', 'country', 'country_full_name', 'city', 'state', 'experiences', 'education', 'languages', 'accomplishment_organisations', 'accomplishment_publications', 'accomplishment_honors_awards', 'accomplishment_patents', 'accomplishment_courses', 'accomplishment_projects', 'accomplishment_test_scores', 'volunteer_work', 'certifications', 'connections', 'people_also_viewed', 'recommendations', 'activities', 'similarly_named_profiles', 'articles', 'groups', 'skills', 'inferred_salary', 'gender', 'birth_date', 'industry', 'extra', 'interests', 'personal_emails', 'personal_numbers'])
